# %%
# add modules to Python's search path
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# import our weighted graph module
from modules import wgraph as gr

# %% [markdown]
# ## Recreate lucaman99's first graph with all the weights set to 1

# %%
edges = [(0, 1), (1, 2), (2, 3), (3, 0), (2, 0), (1, 3), (0, 4), (1, 4), (2, 4), (3, 4), (4, 5), (5, 0), (2, 6), (6, 3)]
g = gr.gen_wgraph_from_edges(edges=edges, unweighted=True)
g.draw()

# %% [markdown]
# ## Same graph with nodes colored according to a cut

# %%
g.draw(cut='0001110')

# %% [markdown]
# ## Recreate the same graph with randomly generated weights

# %%
g = gr.gen_wgraph_from_edges(edges=edges, unweighted=False, max_weight=10.0)
g.draw()

# %% [markdown]
# ## Create a random graph using Erdős–Rényi model with randomly generated weights

# %%
g = gr.gen_random_wgraph(num_nodes=8, edge_creation_prob=0.5, unweighted=False, max_weight=10.0)
g.draw()
