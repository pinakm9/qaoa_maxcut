# %%
# add modules to Python's search path
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from modules import wgraph as gr
from modules import maxcut as mc

# %%
g = gr.gen_random_wgraph(num_nodes=5, edge_creation_prob=0.9)

# %%
mxc = mc.MaxCut(g)
gr.plot_wgraph(g)

# %%
import numpy as np
params = np.random.normal(size=6)

# %%
circ = mxc.build_circuit(params)

# %%
#mxc.run_circuit(circ, 1729)

# %%
mxc.build_objective(1729)

# %%
mxc.solve(6, 2000)
# Out:
# Here are first 5 candidates for optimal cut with corresponding sums of inter-cluster edge weights:
# 00111: 28.5
# 00011: 26.1
# 11101: 11.9
# 11011: 2.6
# 00001: 21.200000000000003

# %%
mxc.classical_objective('11011')
# Out:
# -5.2

# %%
print(mxc.wgraph.edges)
# Out:
# [(0, 1), (0, 3), (0, 4), (1, 2), (1, 4), (2, 3), (3, 4)]

# %%
mxc.wgraph.edges[3, 4]
# Out:
# {'weight': 3.5}
