# %%
# add modules to Python's search path
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# import our weighted graph and max-cut modules
from modules import wgraph as gr
from modules import maxcut as mc

# %%
g = gr.gen_random_wgraph(num_nodes=5, edge_creation_prob=0.9)
g.draw()

# %% [markdown]
# ## Solve max-cut using QAOA

# %%
mxc = mc.MaxCut(g)
mxc.build_objective(num_shots=1729) # the fabled taxi-cab number makes an appearance
mxc.solve(depth=8, max_iter=2000)

# %% [markdown]
# ## View first few solutions

# %%
mxc.view_first_few_solutions(num_sols_to_display=3)
# Out:
# Here are the first 3 candidates for optimal cut with corresponding sums of inter-cluster edge weights:
# Candidate #0 for optimal cut
# ----------------------------
# Cut  : Sum of inter-cluster edge weights
# 01010: 44.6
# Candidate #1 for optimal cut
# ----------------------------
# Cut  : Sum of inter-cluster edge weights
# 01111: 25.2
# Candidate #2 for optimal cut
# ----------------------------
# Cut  : Sum of inter-cluster edge weights
# 11110: 31.9
